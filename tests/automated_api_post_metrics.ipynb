# %% [markdown]
# # Results from Automated Metrics

# %%
# SET UP
import pandas as pd
from datetime import datetime
from tests_to_lib_config import set_path 
config = set_path()
POST_METRICS_CSV = config["POST_METRICS_PATH"]
M_INTITAL_EXTRACT = config["M_INTITAL_EXTRACT"]

# %%
post_metrics = pd.read_csv(POST_METRICS_CSV)
length = len(post_metrics)
print(f"{length} rows of data pulled from Instagram Graph API:")
post_metrics.head()
# Out:
# 1422 rows of data pulled from Instagram Graph API:
#                              name    period  \
# 0                        comments  lifetime
# 1         ig_reels_avg_watch_time  lifetime
# 2  ig_reels_video_view_total_time  lifetime
# 3                           likes  lifetime
# 4                           reach  lifetime
#
#                                      title  \
# 0                                 Comments
# 1  Reels Average Watch Time (milliseconds)
# 2     Video View Total Time (milliseconds)
# 3                                    Likes
# 4                         Accounts reached
#
#                                          description                 id  \
# 0               The number of comments on your reel.  18013117540740395
# 1  This body communicates the definition for reel...  18013117540740395
# 2  This body communicates the definition for reel...  18013117540740395
# 3                  The number of likes on your reel.  18013117540740395
# 4  The number of unique accounts that have seen t...  18013117540740395
#
#      value         datetime_now
# 0        1  2025-03-07 15:16:23
# 1     6747  2025-03-07 15:16:23
# 2  6639898  2025-03-07 15:16:23
# 3       64  2025-03-07 15:16:23
# 4      926  2025-03-07 15:16:23

# %%
post_metrics['Post ID'] = post_metrics['id']
intital_extract = pd.read_csv(M_INTITAL_EXTRACT)
merged_df = pd.merge(post_metrics, intital_extract, on='Post ID', how='left')
print("Data merged with initial extract: ")
merged_df.head()
# Out:
# Data merged with initial extract:
#                              name    period  \
# 0                        comments  lifetime
# 1         ig_reels_avg_watch_time  lifetime
# 2  ig_reels_video_view_total_time  lifetime
# 3                           likes  lifetime
# 4                           reach  lifetime
#
#                                      title  \
# 0                                 Comments
# 1  Reels Average Watch Time (milliseconds)
# 2     Video View Total Time (milliseconds)
# 3                                    Likes
# 4                         Accounts reached
#
#                                          description                 id  \
# 0               The number of comments on your reel.  18013117540740395
# 1  This body communicates the definition for reel...  18013117540740395
# 2  This body communicates the definition for reel...  18013117540740395
# 3                  The number of likes on your reel.  18013117540740395
# 4  The number of unique accounts that have seen t...  18013117540740395
#
#      value       datetime_now_x            Post ID         Account ID  \
# 0        1  2025-03-07 15:16:23  18013117540740395  17841461458191255
# 1     6747  2025-03-07 15:16:23  18013117540740395  17841461458191255
# 2  6639898  2025-03-07 15:16:23  18013117540740395  17841461458191255
# 3       64  2025-03-07 15:16:23  18013117540740395  17841461458191255
# 4      926  2025-03-07 15:16:23  18013117540740395  17841461458191255
#
#   Account username  ... Data comment      Date  Reach Likes Shares Comments  \
# 0      locwithaush  ...          NaN  Lifetime    910    64      1        1
# 1      locwithaush  ...          NaN  Lifetime    910    64      1        1
# 2      locwithaush  ...          NaN  Lifetime    910    64      1        1
# 3      locwithaush  ...          NaN  Lifetime    910    64      1        1
# 4      locwithaush  ...          NaN  Lifetime    910    64      1        1
#
#    Saves Follows       datetime_now_y  Views
# 0      3     5.0  2025-03-07 14:24:42    NaN
# 1      3     5.0  2025-03-07 14:24:42    NaN
# 2      3     5.0  2025-03-07 14:24:42    NaN
# 3      3     5.0  2025-03-07 14:24:42    NaN
# 4      3     5.0  2025-03-07 14:24:42    NaN
#
# [5 rows x 26 columns]

# %%
length = len(merged_df['Post ID'].value_counts())
print(f"Number of posts gathered: {length}")
print(merged_df['Post type'].value_counts())
# Out:
# Number of posts gathered: 143
# Post type
# IG image       650
# IG carousel    520
# IG reel        288
# Name: count, dtype: int64
